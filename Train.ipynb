# %%
# Liên kết với Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Giải nén file darknet được up lên từ máy tính
# %cd /content
# !unzip /content/drive/MyDrive/TransferYolo/darknet14.zip
# %cd /content/darknet
# Out:
# /content
# Archive:  /content/drive/MyDrive/TransferYolo/darknet14.zip
#    creating: darknet/
#    creating: darknet/.git/
#   inflating: darknet/.git/config
#   inflating: darknet/.git/description
#   inflating: darknet/.git/HEAD
#    creating: darknet/.git/hooks/
#   inflating: darknet/.git/hooks/applypatch-msg.sample
#   inflating: darknet/.git/hooks/commit-msg.sample
#   inflating: darknet/.git/hooks/fsmonitor-watchman.sample
#   inflating: darknet/.git/hooks/post-update.sample
#   inflating: darknet/.git/hooks/pre-applypatch.sample
#   inflating: darknet/.git/hooks/pre-commit.sample
#   inflating: darknet/.git/hooks/pre-merge-commit.sample
#   inflating: darknet/.git/hooks/pre-push.sample
#   inflating: darknet/.git/hooks/pre-rebase.sample
#   inflating: darknet/.git/hooks/pre-receive.sample
#   inflating: darknet/.git/hooks/prepare-commit-msg.sample
#   inflating: darknet/.git/hooks/push-to-checkout.sample
#   inflating: darknet/.git/hooks/update.sample
# ...

# %%
# Tiến hành biên dịch (make) source code
# !make
# !chmod +x ./darknet
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:1004:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# Tạo và kết nối thư mục backup
# !rm /content/darknet/backup -r
# !ln -s /content/drive/MyDrive/TransferYolo/backup

# %%
# Cài đặt trình chuyển đổi từ windows sang Linux
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 0s (928 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# Chuyển đổi các file sang Linux
# !dos2unix /content/darknet/train.txt
# !dos2unix /content/darknet/validation.txt
# !dos2unix /content/darknet/yolo.data
# !dos2unix /content/darknet/yolo.names
# !dos2unix /content/darknet/cfg/yolov3.cfg
# Out:
# dos2unix: converting file /content/darknet/train.txt to Unix format...
# dos2unix: converting file /content/darknet/validation.txt to Unix format...
# dos2unix: converting file /content/darknet/yolo.data to Unix format...
# dos2unix: converting file /content/darknet/yolo.names to Unix format...
# dos2unix: converting file /content/darknet/cfg/yolov3.cfg to Unix format...

# %%
# Tiến hành train model
# %cd /content/darknet
# !./darknet detector train yolo.data cfg/yolov3.cfg darknet53.conv.74
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Region 82 Avg IOU: 0.406247, Class: 0.501739, Obj: 0.028522, No Obj: 0.040301, .5R: 0.000000, .75R: 0.000000,  count: 4
# Region 94 Avg IOU: 0.146910, Class: 0.882209, Obj: 0.018630, No Obj: 0.019650, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.008450, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.200543, Class: 0.209064, Obj: 0.014841, No Obj: 0.041118, .5R: 0.000000, .75R: 0.000000,  count: 2
# Region 94 Avg IOU: 0.261847, Class: 0.545438, Obj: 0.015529, No Obj: 0.019452, .5R: 0.000000, .75R: 0.000000,  count: 5
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.008705, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.273287, Class: 0.410665, Obj: 0.014329, No Obj: 0.042430, .5R: 0.000000, .75R: 0.000000,  count: 2
# Region 94 Avg IOU: 0.098720, Class: 0.632023, Obj: 0.031156, No Obj: 0.020174, .5R: 0.000000, .75R: 0.000000,  count: 5
# ...
